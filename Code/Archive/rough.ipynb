# %%
import obspy
import pandas as pd
import obspy.signal.filter

# %%
dt = obspy.read('../Data/2010/HHE.D/HHE.D/MN.WDD..HHE.D.2010.001')
dt += obspy.read('../Data/2010/HHN.D/HHN.D/MN.WDD..HHN.D.2010.001')
dt += obspy.read('../Data/2010/HHZ.D/HHZ.D/MN.WDD..HHZ.D.2010.001')

# %%
all = pd.read_csv("../Data/2010/event-details.csv")

# %%
sp = all[all['spTime'] < 20]

# %%
year = sp.iloc[0]['year']
day = sp.iloc[0]['day']
oTime = sp.iloc[0]['oTime']
date = sp.iloc[0]['date']

# %%
year = '2004'
day = '162'
date = '2004-06-10'
time = '05:44:08.702'

# %%
import obspy

# %%
dt = obspy.read(f'../Data/{year}/MN/WDD/HHE.D/MN.WDD..HHE.D.{year}.{day}')
dt += obspy.read(f'../Data/{year}/MN/WDD/HHN.D/MN.WDD..HHN.D.{year}.{day}')
dt += obspy.read(f'../Data/{year}/MN/WDD/HHZ.D/MN.WDD..HHZ.D.{year}.{day}')

# %%
st.filter("highpass", freq=2.001)
st.plot()
