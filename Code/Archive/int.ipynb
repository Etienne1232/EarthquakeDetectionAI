# %%
from obspy import UTCDateTime
from obspy.clients.fdsn import Client
client = Client("INGV")
t = UTCDateTime("2013-02-27T06:45:00.000")
st = client.get_waveforms("MN", "IDI", "", "HH*", t, t + 60 * 60)
st.plot()
