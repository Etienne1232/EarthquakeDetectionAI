# %%
import obspy

# %%
dt = obspy.read('../Data/DUMP/HHE.D/HHE.D/MN.WDD..HHE.D.2010.001')

# %%
dt.plot()

# %%
dt += obspy.read('../Data/DUMP/HHN.D/HHN.D/MN.WDD..HHN.D.2010.001')
dt += obspy.read('../Data/DUMP/HHZ.D/HHZ.D/MN.WDD..HHZ.D.2010.001')

# %%
print(dt)
# Out:
# 9 Trace(s) in Stream:
# MN.WDD..HHE | 2010-01-01T00:00:04.587403Z - 2010-01-01T08:59:58.424903Z | 80.0 Hz, 2591508 samples
# MN.WDD..HHE | 2010-01-01T08:59:58.360059Z - 2010-01-01T09:25:57.097559Z | 80.0 Hz, 124700 samples
# MN.WDD..HHE | 2010-01-01T09:25:57.187403Z - 2010-01-02T00:00:02.874903Z | 80.0 Hz, 4195656 samples
# MN.WDD..HHN | 2010-01-01T00:00:00.424903Z - 2010-01-01T08:59:55.587403Z | 80.0 Hz, 2591614 samples
# MN.WDD..HHN | 2010-01-01T08:59:55.522559Z - 2010-01-01T09:25:53.960059Z | 80.0 Hz, 124676 samples
# MN.WDD..HHN | 2010-01-01T09:25:54.049903Z - 2010-01-02T00:00:02.162403Z | 80.0 Hz, 4195850 samples
# MN.WDD..HHZ | 2010-01-01T00:00:02.387403Z - 2010-01-01T08:59:57.424903Z | 80.0 Hz, 2591604 samples
# MN.WDD..HHZ | 2010-01-01T08:59:57.360059Z - 2010-01-01T09:25:56.547559Z | 80.0 Hz, 124736 samples
# MN.WDD..HHZ | 2010-01-01T09:25:56.637403Z - 2010-01-02T00:00:03.399903Z | 80.0 Hz, 4195742 samples

# %%
dt.plot()
