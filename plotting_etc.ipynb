# %%
import obspy
from joblib import load

# %%
path = './Data/'

# %%
HHE = path+f"2011/MN/WDD/HHE.D/MN.WDD..HHE.D.2011.070"
HHN = path+f"2011/MN/WDD/HHN.D/MN.WDD..HHN.D.2011.070"
HHZ = path+f"2011/MN/WDD/HHZ.D/MN.WDD..HHZ.D.2011.070"

st = obspy.read(HHE)
st += obspy.read(HHN)
st += obspy.read(HHZ)

# %%
x = obspy.UTCDateTime('2011-03-11T05:59')
y = obspy.UTCDateTime('2011-03-11T06:00')

# %%
st = st.slice(x, y)

# %%
st.plot()

# %%
load('./BEST SET/')
